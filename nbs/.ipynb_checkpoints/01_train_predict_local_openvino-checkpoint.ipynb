# %% [markdown]
# #  Building a State of the Art Bacterial Classifier with fast.ai
#
# The fast.ai library has been breaking records as students use it to produce state of the art results on a myriad of tasks. Some examples given in the course include environmental sound classification and handwritten devanagari prediction.
#
# In this notebook we'll use the library for state of the art bacteria classification with the [DIBaS dataset](http://misztal.edu.pl/software/databases/dibas/). DIBaS (Digital Image of Bacterial Species) contains 660 images, with 33 different genera and species of bacteria.
#
# You can also check out the full blog post on [Building a Bacterial Classifier with fast.ai](https://blog.paperspace.com/building-a-state-of-the-art-bacterial-classifier-with-paperspace-gradient-and-fast-ai/) by Harsh Sikka.

# %% [markdown]
# ## Load libraries

# %%
import os
import requests
import urllib.request
import zipfile
import matplotlib.pyplot as plt
from fastai.vision import *
from fastai.metrics import error_rate
from bs4 import BeautifulSoup

# %% [markdown]
# ## Download and extract bacteria dataset

# %%
if not os.path.exists('/storage/dibas_zips'):
    os.makedirs('/storage/dibas_zips')

if not os.path.exists('storage/dibas_images'):
    os.makedirs('/storage/dibas_images')

# %%
# Parse the webpage; images are saved in a separate .zip file for each strain of bacteria
url = 'http://misztal.edu.pl/software/databases/dibas/'
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
links = [tag['href'] for tag in soup.findAll('a')]

for link in links:
    if ".zip" in link:
        file_name = link.partition("/dibas/")[2]
        urllib.request.urlretrieve(link, '/storage/dibas_zips/' + file_name) 
        zip_ref = zipfile.ZipFile('/storage/dibas_zips/' + file_name, 'r')
        zip_ref.extractall('/storage/dibas_images/')   
        zip_ref.close()
        print("Downloaded and extracted: " + file_name)

# %%
len(os.listdir(('/storage/dibas_images/')))

# %% [markdown]
# ## Verify images

# %%
verify_images('/storage/dibas_images/', delete=True, max_size=500, max_workers=1)

# %% [markdown]
# ## Train our model

# %%
bs = 64
fnames = get_image_files('/storage/data/dibas_images/')
fnames[:5]
# Out:
# [PosixPath('/storage/data/dibas_images/Bacteroides.fragilis_0015.tif'),
#  PosixPath('/storage/data/dibas_images/Enterococcus.faecalis_0007.tif'),
#  PosixPath('/storage/data/dibas_images/Lactobacillus.salivarius_0004.tif'),
#  PosixPath('/storage/data/dibas_images/Propionibacterium.acnes_0002.tif'),
#  PosixPath('/storage/data/dibas_images/Enterococcus.faecium_0018.tif')]

# %%
np.random.seed(42)
pat = r'/([^/]+)_\d+.tif$'
data = ImageDataBunch.from_name_re('/storage/data/dibas_images/', fnames, pat, ds_tfms=get_transforms(), size=24, bs=bs).normalize(imagenet_stats)
print(data)
# Out:
# ImageDataBunch;
#
# Train: LabelList (536 items)
# x: ImageList
# Image (3, 24, 24),Image (3, 24, 24),Image (3, 24, 24),Image (3, 24, 24),Image (3, 24, 24)
# y: CategoryList
# Bacteroides.fragilis,Enterococcus.faecalis,Propionibacterium.acnes,Enterococcus.faecium,Staphylococcus.aureus
# Path: /storage/data/dibas_images;
#
# Valid: LabelList (133 items)
# x: ImageList
# Image (3, 24, 24),Image (3, 24, 24),Image (3, 24, 24),Image (3, 24, 24),Image (3, 24, 24)
# y: CategoryList
# Micrococcus.spp,Lactobacillus.crispatus,Propionibacterium.acnes,Lactobacillus.casei,Enterococcus.faecalis
# Path: /storage/data/dibas_images;
#
# Test: None

# %%
data.show_batch(rows=3, figsize=(7,8))

# %% [markdown]
# ## Find optimal learning rate

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate)
learn.lr_find()
learn.recorder.plot()
# Out:
# /opt/conda/envs/fastai/lib/python3.6/site-packages/fastai/vision/learner.py:106: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# HBox(children=(IntProgress(value=0, max=102502400), HTML(value='')))
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='13', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       84.62% [11/13 00:14<00:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.212219</td>
#       <td>#na#</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.337526</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.215109</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.217442</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.155200</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>4.971719</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>4.596427</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.155946</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.875457</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>4.058018</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>7.209365</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='8', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       25.00% [2/8 00:00<00:02 13.9577]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.save('stage-1-50')
learn.unfreeze()
learn.fit_one_cycle(3, max_lr=slice(1e-6,1e-4))

# %%
learn.load('stage-1-50');
# interp = ClassificationInterpretation.from_learner(learn)
# interp.plot_confusion_matrix(data.classes)

preds,y,losses = learn.get_preds(with_loss=True)
interp = ClassificationInterpretation(learn, preds, y, losses)
interp.plot_confusion_matrix(plot_txt=False)

# %%
img = learn.data.train_ds[0][0]
img.show()

learn.predict(img)
# Out:
# (Category Lactobacillus.crispatus,
#  tensor(10),
#  tensor([0.0270, 0.0702, 0.0810, 0.0231, 0.0040, 0.0108, 0.0128, 0.0192, 0.0542,
#          0.0097, 0.1066, 0.0082, 0.0134, 0.0044, 0.0507, 0.0065, 0.0258, 0.0510,
#          0.0027, 0.0133, 0.0210, 0.0055, 0.0513, 0.0194, 0.0617, 0.0330, 0.0808,
#          0.0648, 0.0256, 0.0076, 0.0270, 0.0081]))

# %% [markdown]
# # Upload model and deploy it w/ gradient

# %% [markdown]
# # Train with the SDK as an experiment

# %% [markdown]
# # Test deployed endpoint for performance

# %%
import json
import requests
deployment_url = "https://clpvt0s6x.paperspacegradient.com/model-serving/deqj8z1ium0gi1"
result = requests.get("{}/metadata".format(deployment_url))

try:
    result_dic = json.loads(result.text)
except ValueError:
    result_dic="The server response is not json format: {}",format(result.text)

print(result_dic)
# Out:
# {'modelSpec': {'name': 'bacteria_classifier', 'version': '1'}, 'metadata': {'signature_def': {'@type': 'type.googleapis.com/tensorflow.serving.SignatureDefMap', 'signatureDef': {'serving_default': {'inputs': {'image': {'name': 'image_3:0', 'dtype': 'DT_FLOAT', 'tensorShape': {'dim': [{'size': '1'}, {'size': '3'}, {'size': '24'}, {'size': '24'}]}}}, 'outputs': {'bacterialclassifier': {'name': 'bacterialclassifier_3:0', 'dtype': 'DT_FLOAT', 'tensorShape': {'dim': [{'size': '1'}, {'size': '32'}]}}}, 'methodName': 'tensorflow/serving/predict'}}}}}

# %%
# !python rest_serving_client.py --images_numpy_path /storage/data/dibas_batch/val_batch.npy --labels_numpy_path /storage/data/dibas_batch/val_labels.npy --input_name image --output_name bacterialclassifier --rest_port 8001 --transpose_input False --rest_url https://clpvt0s6x.paperspacegradient.com/model-serving/deqj8z1ium0gi1
# Out:
# Image data range: 0 : 255
# Start processing:
# 	Model name: resnet
# 	Iterations: 64
# 	Images numpy path: /storage/data/dibas_batch/val_batch.npy
# 	Images in shape: (64, 3, 24, 24)
#
# output shape: (1, 32)
# Iteration 1; Processing time: 60.93 ms; speed 16.41 fps
# output shape: (1, 32)
# Iteration 2; Processing time: 122.39 ms; speed 8.17 fps
# output shape: (1, 32)
# Iteration 3; Processing time: 98.59 ms; speed 10.14 fps
# output shape: (1, 32)
# Iteration 4; Processing time: 99.05 ms; speed 10.10 fps
# output shape: (1, 32)
# Iteration 5; Processing time: 100.28 ms; speed 9.97 fps
# output shape: (1, 32)
# Iteration 6; Processing time: 189.39 ms; speed 5.28 fps
# output shape: (1, 32)
# Iteration 7; Processing time: 100.16 ms; speed 9.98 fps
# output shape: (1, 32)
# Iteration 8; Processing time: 102.68 ms; speed 9.74 fps
# output shape: (1, 32)
# Iteration 46; Processing time: 177.83 ms; speed 5.62 fps
# output shape: (1, 32)
# Iteration 47; Processing time: 97.30 ms; speed 10.28 fps
# output shape: (1, 32)
# Iteration 48; Processing time: 100.23 ms; speed 9.98 fps
# output shape: (1, 32)
# Iteration 49; Processing time: 99.72 ms; speed 10.03 fps
# output shape: (1, 32)
# Iteration 50; Processing time: 97.29 ms; speed 10.28 fps
# output shape: (1, 32)
# Iteration 51; Processing time: 100.36 ms; speed 9.96 fps
# output shape: (1, 32)
# Iteration 52; Processing time: 99.56 ms; speed 10.04 fps
# output shape: (1, 32)
# Iteration 53; Processing time: 96.94 ms; speed 10.32 fps
# output shape: (1, 32)
# Iteration 54; Processing time: 98.93 ms; speed 10.11 fps
# output shape: (1, 32)
# Iteration 55; Processing time: 98.24 ms; speed 10.18 fps
# output shape: (1, 32)
# Iteration 56; Processing time: 99.94 ms; speed 10.01 fps
# output shape: (1, 32)
# Iteration 57; Processing time: 97.12 ms; speed 10.30 fps
# output shape: (1, 32)
# Iteration 58; Processing time: 101.72 ms; speed 9.83 fps
# output shape: (1, 32)
# Iteration 59; Processing time: 95.33 ms; speed 10.49 fps
# output shape: (1, 32)
# Iteration 60; Processing time: 98.43 ms; speed 10.16 fps
# output shape: (1, 32)
# Iteration 61; Processing time: 99.10 ms; speed 10.09 fps
# output shape: (1, 32)
# Iteration 62; Processing time: 97.40 ms; speed 10.27 fps
# output shape: (1, 32)
# Iteration 63; Processing time: 105.83 ms; speed 9.45 fps
# output shape: (1, 32)
# Iteration 64; Processing time: 94.14 ms; speed 10.62 fps
#
# processing time for all iterations
# average time: 100.81 ms; average speed: 9.92 fps
# median time: 98.00 ms; median speed: 10.20 fps
# max time: 189.00 ms; min speed: 5.29 fps
# min time: 60.00 ms; max speed: 16.67 fps
# time percentile 90: 101.00 ms; speed percentile 90: 9.90 fps
# time percentile 50: 98.00 ms; speed percentile 50: 10.20 fps
# time standard deviation: 15.95
# time variance: 254.40

# %% [markdown]
# # Save Model to ONNX

# %%
from torch.autograd import Variable
sz = 24
#model = torch.load('Weights.h5')
model_name = "bacterial_classifier3.onnx"

dummy_input = Variable(torch.randn(1, 3, sz, sz)) # for iOS app, we predict only 1 image at a time, we don't use batch
torch.onnx.export(learn.model, dummy_input, model_name, \
                  input_names=['image'], output_names=['bacterialclassifier'], verbose=True)

# %%
img = learn.data.train_ds[0][0]
img.show()

learn.predict(img)

# %%
# !mkdir /storage/data/dibas_batch/

# %%
val_batch=[np.array(learn.data.valid_ds[i][0].data) for i in range(64)]
val_batch=np.array(val_batch)
val_batch.shape
val_batch=val_batch.transpose([0,1,3,2])
val_batch.shape
np.save('/storage/data/dibas_batch/val_batch', val_batch)
val_labels=[np.array(learn.data.valid_ds[i][0].data) for i in range(64)]
val_labels=np.array(val_labels)
val_labels.shape
val_labels=val_labels.transpose([0,1,3,2])
val_labels.shape
np.save('/storage/data/dibas_batch/val_labels', val_labels)

# %% [markdown]
# ## Convert to OpenVINO IR

# %%
# !python /opt/intel/openvino/deployment_tools/model_optimizer/mo.py --input_model=bacterial_classifier3.onnx -o .

# %%
mv l_openvino_toolkit_p_2020.1.023.tgz /storage

# %%
ls
